# %% [markdown]
# <a href="https://colab.research.google.com/github/smallsmallrice/MSSP-6070/blob/main/Suzy_Xu_Participation_Exercise_Week_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configure plotting in Jupyter
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams.update({
    'figure.figsize': (7.5, 7.5),
    'axes.spines.right': False,
    'axes.spines.left': False,
    'axes.spines.top': False,
    'axes.spines.bottom': False})
# Seed random number generator
import random
from numpy import random as nprand
seed = hash("Network Science in Python") % 2**32
nprand.seed(seed)
random.seed(seed)

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

# %%
# Add members to the graph
G.add_node("Andrea")
G.add_node("Rose")
G.add_node("Karina")
G.add_node("Suzy")

# %%
G.add_edge("Andrea", "Rose")
G.add_edge("Andrea", "Karina")
G.add_edge("Andrea", "Suzy")
G.add_edge("Rose", "Karina")
G.add_edge("Rose", "Suzy")
G.add_edge("Karina", "Suzy")


plt.figure(figsize=(7.5, 7.5))
nx.draw_networkx(G)
